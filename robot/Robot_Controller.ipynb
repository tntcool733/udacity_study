# %% [markdown]
# ## 控制迷宫寻宝机器人
#
# 在这个项目中，你将使用刚刚学到的知识，尝试根据要求，编写代码，来控制一个机器人，在模拟环境中行走，并找到目标宝藏。
#
# 机器人所在的模拟环境中，会包含这样几个因素：机器人的起点、障碍物、宝藏箱。你的任务包括：
#
# 1. 分析模拟环境的数据
# 2. 控制机器人随机行动
# 3. （可选）控制机器人走到终点
#
#
# * 一个良好的含有注释的代码，可以让你的程序可读性更高，尝试为你自己的代码添加相应的注释。

# %% [markdown]
# ---
#
# ---
#
# ## 第一节 分析模拟环境的数据
#
# 首先，只有足够了解机器人所在的环境，我们的机器人才能成功找到目标宝藏，因此首先我们来对机器人所在环境的数据进行分析。在这个部分，会考察你对数据结构、控制流的了解。

# %% [markdown]
# ### 1.1 理解模拟环境数据的储存格式
#
# 首先我们思考这样的问题：如何存储模拟环境的数据呢？
#
# 我们将我们的模拟环境抽象成一个格子世界，每个格子按照坐标编号进行标记；每个格子中会有四个情况，分别为普通格子（可通行）、机器人的起点（可通行）、障碍物（不可通行）、宝藏箱（目标点）。例如，一个模拟环境就可以抽象成3行4列的格子世界，并按这按这样的方法进行存储：
# ```
# environment = [[0,0,0,2],
#                [1,2,0,0],
#                [0,2,3,2]]
# ```
# 我们用了一个列表来保存虚拟世界的数据。外层列表中的每一个元素依然是一个列表，它代表模拟环境中每行的数据。而对于这个列表中的每个元素都是一个数，它们的含义是：
# - 0: 普通格子（可通行）
# - 1: 机器人的起点（可通行）
# - 2: 障碍物（不可通行）
# - 3: 宝藏箱（目标点）
#
# 那么，根据上述的数据，这个迷宫的第二行第一列，是我们机器人的起点。
#
# __注：我们描述的迷宫的坐标位置（第一行第一列），和迷宫下标索引的值（如 `(0,0)`）是不一样的，请注意下标的问题。__
#
#
# 如下的代码，使用了辅助函数，读取了模拟环境的数据，并保存在了 `env_data` 变量中。

# %%
import helper

env_data = helper.fetch_maze()
# Out:
# maze-id 1-1559131753
# [[3, 2, 2, 2, 2, 2, 2, 2, 1],
#  [0, 0, 2, 2, 2, 2, 2, 0, 0],
#  [2, 0, 0, 2, 2, 2, 0, 0, 2],
#  [2, 2, 0, 0, 2, 0, 0, 2, 2],
#  [2, 2, 2, 0, 0, 0, 2, 2, 2]]

# %% [markdown]
# ---
#
#
# **任务1：**在如下代码中，请写代码获得这些值：
#
# 1. 模拟环境的长和宽
# 2. 模拟环境中第3行第6列元素

# %%
import helper

# 模拟环境数据
env_data = helper.fetch_maze()

# 1模拟环境的行数
rows = len(env_data)

# 2模拟环境的列数
columns = len(env_data[0])

# 3取出模拟环境第三行第六列的元素
row_3_col_6 = env_data[2][5]

print("迷宫共有", rows, "行", columns, "列，第三行第六列的元素是", row_3_col_6)
# Out:
# maze-id 1-1559131760
# [[3, 2, 2, 2, 2, 2, 2, 2, 1],
#  [0, 0, 2, 2, 2, 2, 2, 0, 0],
#  [2, 0, 0, 2, 2, 2, 0, 0, 2],
#  [2, 2, 0, 0, 2, 0, 0, 2, 2],
#  [2, 2, 2, 0, 0, 0, 2, 2, 2]]
# 迷宫共有 5 行 9 列，第三行第六列的元素是 2

# %% [markdown]
# ---
#
# ## 1.2 分析模拟环境数据
#
# 接着我们需要对模拟环境的中的数据进行分析。请根据如下的指示，计算相应的值。
#
# ---
#
# **任务2：**在如下代码中，请计算模拟环境中，第一行和第三列的障碍物个数。
#
# 提示：*可以用循环完成。*

# %%
# 0: 普通格子（可通行）
# 2: 障碍物（不可通行）
ordinary_mark = 0
barrier_mark = 2

# 4计算模拟环境中，第一行的的障碍物个数。
number_of_barriers_row1 = env_data[0].count(barrier_mark)

# 5计算模拟环境中，第三列的的障碍物个数。
number_of_barriers_col3 = [l[2] for l in env_data].count(barrier_mark)

print("迷宫中，第一行共有", number_of_barriers_row1, "个障碍物，第三列共有", number_of_barriers_col3, "个障碍物。")
# Out:
# 迷宫中，第一行共有 7 个障碍物，第三列共有 3 个障碍物。

# %%
# %run -i -e test.py RobotControllortTestCase.test_cal_barriers
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ---
#
# **任务3：**在如下代码中：
#
# 1. 创建一个名为 `loc_map` 的字典，它有两个键值，分别为 `start` 和 `destination`，对应的值分别为起点和目标点的坐标，它们以如 `(0,0)` 的形式保存为元组。
# 2. 从字典中取出 `start` 对应的值，保存在 `robot_current_loc` 对应的变量中，这个变量表示小车现在的位置。

# %%
# 1: 机器人的起点（可通行）
# 3: 宝藏箱（目标点）
start_mark = 1
target_mark = 3


def find_row_col_index(mark, data):
    """
    根据节点值，寻找节点坐标
    :param mark: 节点值
    :param data: 模拟环境
    :return: 节点坐标
    """
    row_index = 0
    col_index = 0
    for mark_list in data:
        if mark in mark_list:
            col_index = mark_list.index(mark)
            break
        else:
            row_index += 1
    return row_index, col_index


# 6按照上述要求创建字典
loc_map = {'start': find_row_col_index(start_mark, env_data),
           'destination': find_row_col_index(target_mark, env_data)}

# 7保存机器人当前的位置
robot_current_loc = loc_map['start']

# %%
# %run -i -e test.py RobotControllortTestCase.test_cal_loc_map
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ---
#
# ---
#
# ## 第二节 控制机器人随机漫步
#
# 在这一步中，你需发出指令，控制机器人在环境中随机行动。它会考察你对控制流、调用函数的知识。

# %% [markdown]
# ## 2.1 控制机器人行动
#
# 我们的机器人能够执行四个动作：向上走 `u`、向下走 `d`、向左走 `l`、向右走 `r`。但是，由于有障碍，很多时候机器人的行动并不能成功。所以在这里，你需要实现一个函数，来判断机器人在某个位置，执行某个移动动作是否可行。
#
# ---
#
# **任务4：**在下方代码中，实现名为 `is_move_valid_special` 的函数，它有两个输入，分别为机器人所在的位置坐标 `loc`，以及即将执行的动作 `act`，如 `(1,1)` 及 `u`。接着它的返回是一个布尔值，表明小车在 `loc` 位置下，是否可以执行动作 `act`。
#
#
# 提示1：*可以读取上方定义的 `env_data` 变量，来读取模拟环境的数据。*
#
# 提示2：*在实现函数后，请删去下方的 `pass` 代码。*
#
# 提示3：*我们需要处理边界的情况，即机器人走到了虚拟环境边界时，是不能够走出虚拟环境的。*

# %%
def is_move_valid_special(loc, act):
    """
    判断机器人在某位置，是否可执行某动作
    :param loc: tuple，位置坐标
    :param act: string，动作标示
    :return: boolean，是否可执行
    """
    row_index = loc[0]
    col_index = loc[1]
    if 'u' == act:
        row_index -= 1
    elif 'd' == act:
        row_index += 1
    elif 'l' == act:
        col_index -= 1
    elif 'r' == act:
        col_index += 1
    else:
        print("unknown act:{}, please check the args", act)

    if row_index < 0 or row_index > len(env_data) - 1:
        return False
    if col_index < 0 or col_index > len(env_data[0]) - 1:
        return False
    if env_data[row_index][col_index] == barrier_mark:
        return False
    return True

# %%
# %run -i -e test.py RobotControllortTestCase.test_is_move_valid_special
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ---
# **任务5：**在下方代码中，重新实现一个名为 `is_move_valid` 的函数，它有三个输入，分别为模拟环境的数据 `env_data`、机器人所在的位置坐标 `loc`、以及即将执行的动作 `act`。它的返回值与此前一样，是一个布尔值，表明小车在给定的虚拟环境中的 `loc` 位置下，是否可以执行动作 `act`。

# %%
def is_move_valid(env_data, loc, act):
    """
    判断机器人在某位置，是否可执行某动作
    :param env_data: list，模拟环境
    :param loc: tuple，位置坐标
    :param act: string，动作标示
    :return: boolean，是否可执行
    """
    row_index = loc[0]
    col_index = loc[1]
    if 'u' == act:
        row_index -= 1
    elif 'd' == act:
        row_index += 1
    elif 'l' == act:
        col_index -= 1
    elif 'r' == act:
        col_index += 1
    else:
        print("unknown act:{}, please check the args", act)

    if row_index < 0 or row_index > len(env_data) - 1:
        return False
    if col_index < 0 or col_index > len(env_data[0]) - 1:
        return False
    if env_data[row_index][col_index] == barrier_mark:
        return False
    return True

# %%
# %run -i -e test.py RobotControllortTestCase.test_is_move_valid
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ---
#
# **任务6：**请回答：
#   1. 在任务4及任务5中的实现的两个函数中，`env_data` 这个变量有什么不同？
#   2. 调用``is_move_valid``函数，参数为``env_data_``、``loc_``、``act_``，如果在函数内修改``env_data``是否会改变``env_data_``的值？为什么？
#
# 提示：_可以尝试从变量作用域的角度回答该问题1。_
#
#
# 提示：_可以尝试从可变类型变量和不可变类型变量的角度回答该问题2。_

# %% [markdown]
# **回答：**
# 问题1，答：任务4的函数中的env_data为全局变量，任务5的函数中的env_data为传递参数变量，是局部变量
# 问题2，答：会，list是可变类型，函数中的传参是传递引用，所以改变env_data会修改env_data_的值。
#          如果是非可变类型，那么是传递值，等于复制了一份给函数使用，如int，string等等

# %% [markdown]
# ---
#
# ## 2.2 机器人可行动作
#
# ---
#
# **任务7：**编写一个名为 `valid_actions` 的函数。它有两个输入，分别为虚拟环境的数据 `env_data`，以及机器人所在的位置 `loc`，输出是一个列表，表明机器人在这个位置所有的可行动作。
#
# 提示：*可以尝试调用上方定义的`is_move_valid`函数。*

# %%
def valid_actions(env_data, loc):
    """
    获取机器人所在位置的所有可行动作列表
    :param env_data: list, 模拟环境
    :param loc: tuple, 机器人所在的位置 loc
    :return: list, 机器人在这个位置所有的可行动作列表
    """
    action_list = ['u', 'd', 'l', 'r']
    return [action for action in action_list if is_move_valid(env_data, loc, action)]

# %%
# %run -i -e test.py RobotControllortTestCase.test_valid_actions
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ---
#
# ## 2.3 移动机器人
#
# 当机器人收到一个动作的时候，你机器人的位置应发生相应的变化。
#
# **任务8：**编写一个名为 `move_robot` 的函数，它有两个输入，分别为机器人当前所在的位置 `loc` 和即将执行的动作 `act`。接着会返回机器人执行动作之后的新位置 `new_loc`。

# %%
def move_robot(loc, act):
    """
    移动机器人，返回移动后的新位置
    :param loc: tuple, 机器人所在位置
    :param act: string, 移动动作
    :return: tuple, 移动后的新位置
    """
    if is_move_valid(env_data, loc, act):
        if 'u' == act:
            return loc[0] - 1, loc[1]
        elif 'd' == act:
            return loc[0] + 1, loc[1]
        elif 'l' == act:
            return loc[0], loc[1] - 1
        elif 'r' == act:
            return loc[0], loc[1] + 1
        else:
            print("unknown act:{}, please check the args", act)
    else:
        # 如果不能移动，则返回原位置
        return loc

# %%
# %run -i -e test.py RobotControllortTestCase.test_move_robot
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %% [markdown]
# ---
#
# ## 2.4 随机移动机器人
#
# 接着，我们尝试在虚拟环境中随机移动机器人，看看会有什么效果。
#
# **任务9：**编写一个名为 `random_choose_actions` 的函数，它有两个输入，分别为虚拟环境的数据 `env_data`，以及机器人所在的位置 `loc`。机器人会执行一个300次的循环，每次循环，他会执行以下任务：
#
# 1. 利用上方定义的 `valid_actions` 函数，找出当前位置下，机器人可行的动作；
# 2. 利用 `random` 库中的 `choice` 函数，从机器人可行的动作中，随机挑选出一个动作；
# 3. 接着根据这个动作，利用上方定义的 `move_robot` 函数，来移动机器人，并更新机器人的位置；
# 4. 当机器人走到终点时，输出“在第n个回合找到宝藏！”。
#
# 提示：如果机器人无法在300个回合内找到宝藏的话，试试看增大这个数字，也许会有不错的效果 :P

# %%
import random

def do_random_choose(round_num, loc, target):
    """
    随机选择机器人移动动作，可传递执行回合数
    :param round_num: int, 回合数
    :param loc: tuple, 机器人位置
    :param target: void，无返回
    :return:
    """
    loc_now = loc
    for step in range(round_num):
        if loc_now == target:
            print("在第{}个回合找到宝藏！".format(step + 1))
            break
        else:
            valid_action_list = valid_actions(env_data, loc_now)
            action = random.choice(valid_action_list)
            loc_now = move_robot(loc_now, action)
            print("robot现在在位置{}, 回合{}".format(loc_now, step + 1))

def random_choose_actions(env_data, loc):
    """
    随机选择机器人移动动作，尝试达到目标找到宝藏
    :param env_data: list，模拟环境
    :param loc: tuple, 机器人位置
    :return: void，无返回
    """
    target = find_row_col_index(target_mark, env_data)
    do_random_choose(300, loc, target)
    do_random_choose(1000, loc, target)

# %%
# 运行
random_choose_actions(env_data, robot_current_loc)
# Out:
# robot现在在位置(1, 8), 回合1
# robot现在在位置(1, 7), 回合2
# robot现在在位置(2, 7), 回合3
# robot现在在位置(1, 7), 回合4
# robot现在在位置(2, 7), 回合5
# robot现在在位置(1, 7), 回合6
# robot现在在位置(1, 8), 回合7
# robot现在在位置(0, 8), 回合8
# robot现在在位置(1, 8), 回合9
# robot现在在位置(1, 7), 回合10
# robot现在在位置(1, 8), 回合11
# robot现在在位置(0, 8), 回合12
# robot现在在位置(1, 8), 回合13
# robot现在在位置(1, 7), 回合14
# robot现在在位置(2, 7), 回合15
# robot现在在位置(1, 7), 回合16
# robot现在在位置(2, 7), 回合17
# robot现在在位置(2, 6), 回合18
# robot现在在位置(3, 6), 回合19
# robot现在在位置(2, 6), 回合20
# robot现在在位置(3, 6), 回合21
# robot现在在位置(2, 6), 回合22
# robot现在在位置(3, 6), 回合23
# robot现在在位置(2, 6), 回合24
# robot现在在位置(2, 7), 回合25
# robot现在在位置(1, 7), 回合26
# robot现在在位置(2, 7), 回合27
# robot现在在位置(2, 6), 回合28
# robot现在在位置(2, 7), 回合29
# robot现在在位置(2, 6), 回合30
# robot现在在位置(2, 7), 回合31
# robot现在在位置(1, 7), 回合32
# robot现在在位置(2, 7), 回合33
# robot现在在位置(1, 7), 回合34
# robot现在在位置(2, 7), 回合35
# robot现在在位置(1, 7), 回合36
# robot现在在位置(2, 7), 回合37
# robot现在在位置(2, 6), 回合38
# robot现在在位置(2, 7), 回合39
# robot现在在位置(2, 6), 回合40
# robot现在在位置(2, 7), 回合41
# robot现在在位置(2, 6), 回合42
# robot现在在位置(2, 7), 回合43
# robot现在在位置(2, 6), 回合44
# robot现在在位置(3, 6), 回合45
# robot现在在位置(2, 6), 回合46
# robot现在在位置(3, 6), 回合47
# robot现在在位置(3, 5), 回合48
# robot现在在位置(4, 5), 回合49
# robot现在在位置(4, 4), 回合50
# robot现在在位置(4, 3), 回合51
# robot现在在位置(3, 3), 回合52
# robot现在在位置(4, 3), 回合53
# robot现在在位置(4, 4), 回合54
# robot现在在位置(4, 5), 回合55
# robot现在在位置(4, 4), 回合56
# robot现在在位置(4, 5), 回合57
# robot现在在位置(4, 4), 回合58
# robot现在在位置(4, 3), 回合59
# robot现在在位置(3, 3), 回合60
# robot现在在位置(3, 2), 回合61
# robot现在在位置(3, 3), 回合62
# robot现在在位置(3, 2), 回合63
# robot现在在位置(2, 2), 回合64
# robot现在在位置(2, 1), 回合65
# robot现在在位置(2, 2), 回合66
# robot现在在位置(3, 2), 回合67
# robot现在在位置(3, 3), 回合68
# robot现在在位置(3, 2), 回合69
# robot现在在位置(3, 3), 回合70
# robot现在在位置(4, 3), 回合71
# robot现在在位置(3, 3), 回合72
# robot现在在位置(3, 2), 回合73
# robot现在在位置(3, 3), 回合74
# robot现在在位置(4, 3), 回合75
# robot现在在位置(3, 3), 回合76
# robot现在在位置(4, 3), 回合77
# robot现在在位置(4, 4), 回合78
# robot现在在位置(4, 3), 回合79
# robot现在在位置(3, 3), 回合80
# robot现在在位置(3, 2), 回合81
# robot现在在位置(3, 3), 回合82
# robot现在在位置(4, 3), 回合83
# robot现在在位置(4, 4), 回合84
# robot现在在位置(4, 3), 回合85
# robot现在在位置(3, 3), 回合86
# robot现在在位置(3, 2), 回合87
# robot现在在位置(3, 3), 回合88
# robot现在在位置(3, 2), 回合89
# robot现在在位置(3, 3), 回合90
# robot现在在位置(3, 2), 回合91
# robot现在在位置(3, 3), 回合92
# robot现在在位置(3, 2), 回合93
# robot现在在位置(3, 3), 回合94
# robot现在在位置(4, 3), 回合95
# robot现在在位置(3, 3), 回合96
# robot现在在位置(4, 3), 回合97
# robot现在在位置(3, 3), 回合98
# robot现在在位置(4, 3), 回合99
# robot现在在位置(4, 4), 回合100
# robot现在在位置(4, 5), 回合101
# robot现在在位置(4, 4), 回合102
# robot现在在位置(4, 5), 回合103
# robot现在在位置(3, 5), 回合104
# robot现在在位置(4, 5), 回合105
# robot现在在位置(4, 4), 回合106
# robot现在在位置(4, 5), 回合107
# robot现在在位置(3, 5), 回合108
# robot现在在位置(3, 6), 回合109
# robot现在在位置(3, 5), 回合110
# robot现在在位置(4, 5), 回合111
# robot现在在位置(4, 4), 回合112
# robot现在在位置(4, 5), 回合113
# robot现在在位置(3, 5), 回合114
# robot现在在位置(3, 6), 回合115
# robot现在在位置(3, 5), 回合116
# robot现在在位置(4, 5), 回合117
# robot现在在位置(3, 5), 回合118
# robot现在在位置(4, 5), 回合119
# robot现在在位置(3, 5), 回合120
# robot现在在位置(3, 6), 回合121
# robot现在在位置(2, 6), 回合122
# robot现在在位置(3, 6), 回合123
# robot现在在位置(3, 5), 回合124
# robot现在在位置(4, 5), 回合125
# robot现在在位置(3, 5), 回合126
# robot现在在位置(4, 5), 回合127
# robot现在在位置(4, 4), 回合128
# robot现在在位置(4, 3), 回合129
# robot现在在位置(4, 4), 回合130
# robot现在在位置(4, 3), 回合131
# robot现在在位置(3, 3), 回合132
# robot现在在位置(4, 3), 回合133
# robot现在在位置(3, 3), 回合134
# robot现在在位置(4, 3), 回合135
# robot现在在位置(3, 3), 回合136
# robot现在在位置(4, 3), 回合137
# robot现在在位置(3, 3), 回合138
# robot现在在位置(3, 2), 回合139
# robot现在在位置(2, 2), 回合140
# robot现在在位置(2, 1), 回合141
# robot现在在位置(1, 1), 回合142
# robot现在在位置(1, 0), 回合143
# robot现在在位置(0, 0), 回合144
# 在第145个回合找到宝藏！
# robot现在在位置(1, 8), 回合1
# robot现在在位置(1, 7), 回合2
# robot现在在位置(2, 7), 回合3
# robot现在在位置(1, 7), 回合4
# robot现在在位置(1, 8), 回合5
# robot现在在位置(0, 8), 回合6
# robot现在在位置(1, 8), 回合7
# robot现在在位置(1, 7), 回合8
# robot现在在位置(1, 8), 回合9
# robot现在在位置(1, 7), 回合10
# robot现在在位置(2, 7), 回合11
# robot现在在位置(2, 6), 回合12
# robot现在在位置(2, 7), 回合13
# robot现在在位置(2, 6), 回合14
# robot现在在位置(2, 7), 回合15
# robot现在在位置(1, 7), 回合16
# robot现在在位置(1, 8), 回合17
# robot现在在位置(1, 7), 回合18
# robot现在在位置(2, 7), 回合19
# robot现在在位置(2, 6), 回合20
# robot现在在位置(2, 7), 回合21
# robot现在在位置(2, 6), 回合22
# robot现在在位置(2, 7), 回合23
# robot现在在位置(2, 6), 回合24
# robot现在在位置(2, 7), 回合25
# robot现在在位置(1, 7), 回合26
# robot现在在位置(1, 8), 回合27
# robot现在在位置(0, 8), 回合28
# robot现在在位置(1, 8), 回合29
# robot现在在位置(0, 8), 回合30
# robot现在在位置(1, 8), 回合31
# robot现在在位置(1, 7), 回合32
# robot现在在位置(1, 8), 回合33
# robot现在在位置(1, 7), 回合34
# robot现在在位置(1, 8), 回合35
# robot现在在位置(1, 7), 回合36
# robot现在在位置(1, 8), 回合37
# robot现在在位置(0, 8), 回合38
# robot现在在位置(1, 8), 回合39
# robot现在在位置(1, 7), 回合40
# robot现在在位置(1, 8), 回合41
# robot现在在位置(1, 7), 回合42
# robot现在在位置(1, 8), 回合43
# robot现在在位置(0, 8), 回合44
# robot现在在位置(1, 8), 回合45
# robot现在在位置(1, 7), 回合46
# robot现在在位置(1, 8), 回合47
# robot现在在位置(0, 8), 回合48
# robot现在在位置(1, 8), 回合49
# robot现在在位置(0, 8), 回合50
# robot现在在位置(1, 8), 回合51
# robot现在在位置(1, 7), 回合52
# robot现在在位置(2, 7), 回合53
# robot现在在位置(1, 7), 回合54
# robot现在在位置(1, 8), 回合55
# robot现在在位置(0, 8), 回合56
# robot现在在位置(1, 8), 回合57
# robot现在在位置(1, 7), 回合58
# robot现在在位置(1, 8), 回合59
# robot现在在位置(0, 8), 回合60
# robot现在在位置(1, 8), 回合61
# robot现在在位置(0, 8), 回合62
# robot现在在位置(1, 8), 回合63
# robot现在在位置(1, 7), 回合64
# robot现在在位置(1, 8), 回合65
# robot现在在位置(1, 7), 回合66
# robot现在在位置(1, 8), 回合67
# robot现在在位置(1, 7), 回合68
# robot现在在位置(1, 8), 回合69
# robot现在在位置(0, 8), 回合70
# robot现在在位置(1, 8), 回合71
# robot现在在位置(1, 7), 回合72
# robot现在在位置(1, 8), 回合73
# robot现在在位置(1, 7), 回合74
# robot现在在位置(2, 7), 回合75
# robot现在在位置(1, 7), 回合76
# robot现在在位置(1, 8), 回合77
# robot现在在位置(1, 7), 回合78
# robot现在在位置(1, 8), 回合79
# robot现在在位置(0, 8), 回合80
# robot现在在位置(1, 8), 回合81
# robot现在在位置(1, 7), 回合82
# robot现在在位置(2, 7), 回合83
# robot现在在位置(1, 7), 回合84
# robot现在在位置(1, 8), 回合85
# robot现在在位置(1, 7), 回合86
# robot现在在位置(1, 8), 回合87
# robot现在在位置(0, 8), 回合88
# robot现在在位置(1, 8), 回合89
# robot现在在位置(1, 7), 回合90
# robot现在在位置(2, 7), 回合91
# robot现在在位置(2, 6), 回合92
# robot现在在位置(2, 7), 回合93
# robot现在在位置(2, 6), 回合94
# robot现在在位置(2, 7), 回合95
# robot现在在位置(1, 7), 回合96
# robot现在在位置(2, 7), 回合97
# robot现在在位置(1, 7), 回合98
# robot现在在位置(1, 8), 回合99
# robot现在在位置(1, 7), 回合100
# robot现在在位置(1, 8), 回合101
# robot现在在位置(1, 7), 回合102
# robot现在在位置(2, 7), 回合103
# robot现在在位置(2, 6), 回合104
# robot现在在位置(2, 7), 回合105
# robot现在在位置(1, 7), 回合106
# robot现在在位置(2, 7), 回合107
# robot现在在位置(1, 7), 回合108
# robot现在在位置(2, 7), 回合109
# robot现在在位置(1, 7), 回合110
# robot现在在位置(2, 7), 回合111
# robot现在在位置(1, 7), 回合112
# robot现在在位置(1, 8), 回合113
# robot现在在位置(0, 8), 回合114
# robot现在在位置(1, 8), 回合115
# robot现在在位置(1, 7), 回合116
# robot现在在位置(2, 7), 回合117
# robot现在在位置(2, 6), 回合118
# robot现在在位置(3, 6), 回合119
# robot现在在位置(2, 6), 回合120
# robot现在在位置(2, 7), 回合121
# robot现在在位置(2, 6), 回合122
# robot现在在位置(3, 6), 回合123
# robot现在在位置(2, 6), 回合124
# robot现在在位置(2, 7), 回合125
# robot现在在位置(2, 6), 回合126
# robot现在在位置(2, 7), 回合127
# robot现在在位置(2, 6), 回合128
# robot现在在位置(3, 6), 回合129
# robot现在在位置(2, 6), 回合130
# robot现在在位置(3, 6), 回合131
# robot现在在位置(3, 5), 回合132
# robot现在在位置(4, 5), 回合133
# robot现在在位置(3, 5), 回合134
# robot现在在位置(3, 6), 回合135
# robot现在在位置(3, 5), 回合136
# robot现在在位置(4, 5), 回合137
# robot现在在位置(3, 5), 回合138
# robot现在在位置(4, 5), 回合139
# robot现在在位置(4, 4), 回合140
# robot现在在位置(4, 3), 回合141
# robot现在在位置(4, 4), 回合142
# robot现在在位置(4, 5), 回合143
# robot现在在位置(3, 5), 回合144
# robot现在在位置(3, 6), 回合145
# robot现在在位置(2, 6), 回合146
# robot现在在位置(2, 7), 回合147
# robot现在在位置(2, 6), 回合148
# robot现在在位置(2, 7), 回合149
# robot现在在位置(1, 7), 回合150
# robot现在在位置(2, 7), 回合151
# robot现在在位置(1, 7), 回合152
# robot现在在位置(1, 8), 回合153
# robot现在在位置(0, 8), 回合154
# robot现在在位置(1, 8), 回合155
# robot现在在位置(0, 8), 回合156
# robot现在在位置(1, 8), 回合157
# robot现在在位置(0, 8), 回合158
# robot现在在位置(1, 8), 回合159
# robot现在在位置(1, 7), 回合160
# robot现在在位置(2, 7), 回合161
# robot现在在位置(2, 6), 回合162
# robot现在在位置(3, 6), 回合163
# robot现在在位置(2, 6), 回合164
# robot现在在位置(3, 6), 回合165
# robot现在在位置(3, 5), 回合166
# robot现在在位置(4, 5), 回合167
# robot现在在位置(4, 4), 回合168
# robot现在在位置(4, 5), 回合169
# robot现在在位置(3, 5), 回合170
# robot现在在位置(3, 6), 回合171
# robot现在在位置(2, 6), 回合172
# robot现在在位置(3, 6), 回合173
# robot现在在位置(2, 6), 回合174
# robot现在在位置(2, 7), 回合175
# robot现在在位置(2, 6), 回合176
# robot现在在位置(2, 7), 回合177
# robot现在在位置(1, 7), 回合178
# robot现在在位置(2, 7), 回合179
# robot现在在位置(2, 6), 回合180
# robot现在在位置(3, 6), 回合181
# robot现在在位置(3, 5), 回合182
# robot现在在位置(4, 5), 回合183
# robot现在在位置(4, 4), 回合184
# robot现在在位置(4, 3), 回合185
# robot现在在位置(4, 4), 回合186
# robot现在在位置(4, 5), 回合187
# robot现在在位置(3, 5), 回合188
# robot现在在位置(3, 6), 回合189
# robot现在在位置(2, 6), 回合190
# robot现在在位置(3, 6), 回合191
# robot现在在位置(3, 5), 回合192
# robot现在在位置(3, 6), 回合193
# robot现在在位置(3, 5), 回合194
# robot现在在位置(4, 5), 回合195
# robot现在在位置(4, 4), 回合196
# robot现在在位置(4, 5), 回合197
# robot现在在位置(3, 5), 回合198
# robot现在在位置(4, 5), 回合199
# robot现在在位置(4, 4), 回合200
# robot现在在位置(4, 3), 回合201
# robot现在在位置(4, 4), 回合202
# robot现在在位置(4, 5), 回合203
# robot现在在位置(4, 4), 回合204
# robot现在在位置(4, 5), 回合205
# robot现在在位置(4, 4), 回合206
# robot现在在位置(4, 3), 回合207
# robot现在在位置(3, 3), 回合208
# robot现在在位置(3, 2), 回合209
# robot现在在位置(2, 2), 回合210
# robot现在在位置(2, 1), 回合211
# robot现在在位置(2, 2), 回合212
# robot现在在位置(3, 2), 回合213
# robot现在在位置(2, 2), 回合214
# robot现在在位置(2, 1), 回合215
# robot现在在位置(2, 2), 回合216
# robot现在在位置(3, 2), 回合217
# robot现在在位置(3, 3), 回合218
# robot现在在位置(3, 2), 回合219
# robot现在在位置(3, 3), 回合220
# robot现在在位置(4, 3), 回合221
# robot现在在位置(4, 4), 回合222
# robot现在在位置(4, 5), 回合223
# robot现在在位置(3, 5), 回合224
# robot现在在位置(3, 6), 回合225
# robot现在在位置(2, 6), 回合226
# robot现在在位置(2, 7), 回合227
# robot现在在位置(2, 6), 回合228
# robot现在在位置(3, 6), 回合229
# robot现在在位置(2, 6), 回合230
# robot现在在位置(2, 7), 回合231
# robot现在在位置(2, 6), 回合232
# robot现在在位置(2, 7), 回合233
# robot现在在位置(1, 7), 回合234
# robot现在在位置(2, 7), 回合235
# robot现在在位置(1, 7), 回合236
# robot现在在位置(1, 8), 回合237
# robot现在在位置(0, 8), 回合238
# robot现在在位置(1, 8), 回合239
# robot现在在位置(1, 7), 回合240
# robot现在在位置(2, 7), 回合241
# robot现在在位置(2, 6), 回合242
# robot现在在位置(3, 6), 回合243
# robot现在在位置(2, 6), 回合244
# robot现在在位置(2, 7), 回合245
# robot现在在位置(2, 6), 回合246
# robot现在在位置(3, 6), 回合247
# robot现在在位置(2, 6), 回合248
# robot现在在位置(2, 7), 回合249
# robot现在在位置(1, 7), 回合250
# robot现在在位置(2, 7), 回合251
# robot现在在位置(2, 6), 回合252
# robot现在在位置(2, 7), 回合253
# robot现在在位置(2, 6), 回合254
# robot现在在位置(3, 6), 回合255
# robot现在在位置(2, 6), 回合256
# robot现在在位置(3, 6), 回合257
# robot现在在位置(3, 5), 回合258
# robot现在在位置(3, 6), 回合259
# robot现在在位置(2, 6), 回合260
# robot现在在位置(3, 6), 回合261
# robot现在在位置(2, 6), 回合262
# robot现在在位置(2, 7), 回合263
# robot现在在位置(2, 6), 回合264
# robot现在在位置(2, 7), 回合265
# robot现在在位置(1, 7), 回合266
# robot现在在位置(1, 8), 回合267
# robot现在在位置(1, 7), 回合268
# robot现在在位置(2, 7), 回合269
# robot现在在位置(2, 6), 回合270
# robot现在在位置(3, 6), 回合271
# robot现在在位置(2, 6), 回合272
# robot现在在位置(3, 6), 回合273
# robot现在在位置(3, 5), 回合274
# robot现在在位置(3, 6), 回合275
# robot现在在位置(2, 6), 回合276
# robot现在在位置(3, 6), 回合277
# robot现在在位置(2, 6), 回合278
# robot现在在位置(2, 7), 回合279
# robot现在在位置(2, 6), 回合280
# robot现在在位置(2, 7), 回合281
# robot现在在位置(2, 6), 回合282
# robot现在在位置(2, 7), 回合283
# robot现在在位置(1, 7), 回合284
# robot现在在位置(1, 8), 回合285
# robot现在在位置(1, 7), 回合286
# robot现在在位置(1, 8), 回合287
# robot现在在位置(0, 8), 回合288
# robot现在在位置(1, 8), 回合289
# robot现在在位置(0, 8), 回合290
# robot现在在位置(1, 8), 回合291
# robot现在在位置(0, 8), 回合292
# robot现在在位置(1, 8), 回合293
# robot现在在位置(0, 8), 回合294
# robot现在在位置(1, 8), 回合295
# robot现在在位置(1, 7), 回合296
# robot现在在位置(2, 7), 回合297
# robot现在在位置(1, 7), 回合298
# robot现在在位置(2, 7), 回合299
# robot现在在位置(1, 7), 回合300
# robot现在在位置(2, 7), 回合301
# robot现在在位置(1, 7), 回合302
# robot现在在位置(2, 7), 回合303
# robot现在在位置(2, 6), 回合304
# robot现在在位置(2, 7), 回合305
# robot现在在位置(1, 7), 回合306
# robot现在在位置(2, 7), 回合307
# robot现在在位置(1, 7), 回合308
# robot现在在位置(2, 7), 回合309
# robot现在在位置(1, 7), 回合310
# robot现在在位置(1, 8), 回合311
# robot现在在位置(0, 8), 回合312
# robot现在在位置(1, 8), 回合313
# robot现在在位置(0, 8), 回合314
# robot现在在位置(1, 8), 回合315
# robot现在在位置(1, 7), 回合316
# robot现在在位置(1, 8), 回合317
# robot现在在位置(0, 8), 回合318
# robot现在在位置(1, 8), 回合319
# robot现在在位置(1, 7), 回合320
# robot现在在位置(1, 8), 回合321
# robot现在在位置(1, 7), 回合322
# robot现在在位置(2, 7), 回合323
# robot现在在位置(1, 7), 回合324
# robot现在在位置(1, 8), 回合325
# robot现在在位置(0, 8), 回合326
# robot现在在位置(1, 8), 回合327
# robot现在在位置(0, 8), 回合328
# robot现在在位置(1, 8), 回合329
# robot现在在位置(1, 7), 回合330
# robot现在在位置(1, 8), 回合331
# robot现在在位置(0, 8), 回合332
# robot现在在位置(1, 8), 回合333
# robot现在在位置(1, 7), 回合334
# robot现在在位置(1, 8), 回合335
# robot现在在位置(0, 8), 回合336
# robot现在在位置(1, 8), 回合337
# robot现在在位置(0, 8), 回合338
# robot现在在位置(1, 8), 回合339
# robot现在在位置(1, 7), 回合340
# robot现在在位置(2, 7), 回合341
# robot现在在位置(1, 7), 回合342
# robot现在在位置(2, 7), 回合343
# robot现在在位置(1, 7), 回合344
# robot现在在位置(2, 7), 回合345
# robot现在在位置(1, 7), 回合346
# robot现在在位置(2, 7), 回合347
# robot现在在位置(2, 6), 回合348
# robot现在在位置(3, 6), 回合349
# robot现在在位置(2, 6), 回合350
# robot现在在位置(3, 6), 回合351
# robot现在在位置(2, 6), 回合352
# robot现在在位置(2, 7), 回合353
# robot现在在位置(1, 7), 回合354
# robot现在在位置(2, 7), 回合355
# robot现在在位置(2, 6), 回合356
# robot现在在位置(3, 6), 回合357
# robot现在在位置(3, 5), 回合358
# robot现在在位置(4, 5), 回合359
# robot现在在位置(4, 4), 回合360
# robot现在在位置(4, 5), 回合361
# robot现在在位置(3, 5), 回合362
# robot现在在位置(4, 5), 回合363
# robot现在在位置(3, 5), 回合364
# robot现在在位置(4, 5), 回合365
# robot现在在位置(4, 4), 回合366
# robot现在在位置(4, 3), 回合367
# robot现在在位置(3, 3), 回合368
# robot现在在位置(3, 2), 回合369
# robot现在在位置(2, 2), 回合370
# robot现在在位置(2, 1), 回合371
# robot现在在位置(2, 2), 回合372
# robot现在在位置(2, 1), 回合373
# robot现在在位置(1, 1), 回合374
# robot现在在位置(1, 0), 回合375
# robot现在在位置(1, 1), 回合376
# robot现在在位置(2, 1), 回合377
# robot现在在位置(1, 1), 回合378
# robot现在在位置(2, 1), 回合379
# robot现在在位置(1, 1), 回合380
# robot现在在位置(1, 0), 回合381
# robot现在在位置(0, 0), 回合382
# 在第383个回合找到宝藏！

# %% [markdown]
# ---
#
# ---
#
# ## （可选）第三节 控制机器人走到终点
#
# ## 3.1 控制机器人走到终点
#
# 在这里，你将综合上述的知识，编码控制机器人走到终点。这个任务对刚刚入门的你来说可能有些挑战，所以它是一个选做题。
#
# **任务10**：尝试实现一个算法，能够对给定的模拟环境，输出机器人的行动策略，使之能够走到终点。
#
# 提示：_你可以尝试参考：_
# * 深度/广度优先算法。
#     以及以下参考资料：
#     1. https://blog.csdn.net/raphealguo/article/details/7523411
#     2. https://www.cnblogs.com/yupeng/p/3414736.html
# * A星算法。
#     以及以下参考资料：
#     1. https://baike.baidu.com/item/A%2A算法
#     2. https://blog.csdn.net/hitwhylz/article/details/23089415

# %%
# 任务10：尝试实现一个算法，能够对给定的模拟环境，输出机器人的行动策略，使之能够走到终点。

def cal_f_path(start, target):
    """
    由于该robot只支持单格上下左右移动，距离一致，所以A*算法的距离F=G(某点到上下左右距离均为1)+H，只需要计算H即可
    :param start: tuple, 开始位置
    :param target: tuple, 终点位置
    :return: int, 路径长度值
    """
    return abs(target[0] - start[0]) + abs(target[1] - start[1])


def find_min_f_node(node_list, target):
    """
    寻找队列中f路径值最小的节点
    :param node_list: list, 节点列表
    :param target: tuple, f路径要到达的节点
    :return: tuple, f路径最小节点
    """
    f_path_list = [cal_f_path(node, target) for node in node_list]
    return node_list[f_path_list.index(min(f_path_list))]


def valid_action_node(env_data, loc):
    """
    寻找当前位置可移动的节点
    :param env_data: list, 模拟环境
    :param loc: tuple, 当前位置
    :return: list, 可移动节点
    """
    valid_node_list = []
    valid_action_list = valid_actions(env_data, loc)
    for valid_action in valid_action_list:
        if 'u' == valid_action:
            valid_node_list.append((loc[0] - 1, loc[1]))
        elif 'd' == valid_action:
            valid_node_list.append((loc[0] + 1, loc[1]))
        elif 'l' == valid_action:
            valid_node_list.append((loc[0], loc[1] - 1))
        elif 'r' == valid_action:
            valid_node_list.append((loc[0], loc[1] + 1))
    return valid_node_list


def act_between_nodes(node1, node2):
    """
    查询节点1到节点2的移动动作
    :param node1: tuple, 节点1坐标
    :param node2: tuple, 节点2坐标
    :return: string, 'u'/'d'/'l'/'r'
    """
    row_cal = node2[0] - node1[0]
    col_cal = node2[1] - node1[1]
    if row_cal == -1 and col_cal == 0:
        return 'u'
    if row_cal == 1 and col_cal == 0:
        return 'd'
    if row_cal == 0 and col_cal == -1:
        return 'l'
    if row_cal == 0 and col_cal == 1:
        return 'r'
    return 'unknown action!'


def reach_destination_quickly(env_data):
    """
    快速寻找宝藏
    :param env_data: list, 模拟环境
    :return: void, 返回空
    """
    start_node = find_row_col_index(start_mark, env_data)
    target_node = find_row_col_index(target_mark, env_data)
    open_list = []
    close_list = []
    node_path = []
    act_path = []
    from_node = ()

    open_list.append(start_node)
    while True:
        min_f_node = find_min_f_node(open_list, target_node)
        node_path.append(min_f_node)
        # from_node空则跳过判定
        if from_node:
            act_path.append(act_between_nodes(from_node, min_f_node))

        open_list.remove(min_f_node)
        close_list.append(min_f_node)
        if min_f_node == target_node:
            # 到达终点
            break

        # 存在valid_action_node中，并且不在close_list和open_list中, 才准备加入open_list
        node_list_to_append_open = [node for node in valid_action_node(env_data, min_f_node)
                                    if node not in close_list and node not in open_list]
        open_list += node_list_to_append_open
        from_node = min_f_node

    print("起点为:{}, 终点为:{}".format(start_node, target_node))
    print("预测路径为:{}".format(node_path))
    print("预测动作:{}".format(act_path))
    if node_path[-1] == target_node:
        print("预测动作可寻找到宝藏位置:{}".format(node_path[-1]))

reach_destination_quickly(env_data)
# Out:
# 起点为:(0, 8), 终点为:(0, 0)
# 预测路径为:[(0, 8), (1, 8), (1, 7), (2, 7), (2, 6), (3, 6), (3, 5), (4, 5), (4, 4), (4, 3), (3, 3), (3, 2), (2, 2), (2, 1), (1, 1), (1, 0), (0, 0)]
# 预测动作:['d', 'l', 'd', 'l', 'd', 'l', 'd', 'l', 'l', 'u', 'l', 'u', 'l', 'u', 'l', 'u']
# 预测动作可寻找到宝藏位置:(0, 0)

# %% [markdown]
# > 注意: 当你写完了所有的代码，并且回答了所有的问题。你就可以把你的 iPython Notebook 导出成 HTML 文件。你可以在菜单栏，这样导出**File -> Download as -> HTML (.html)**把这个 HTML 和这个 iPython notebook 一起做为你的作业提交。
